# %%
import pandas as pd
db = pd.read_csv('./dataset/vehicles.csv')

# %%
db.columns[0:10]
# Out:
# Index(['accident_id', 'Vehicle_Reference', 'Vehicle_Type',
#        'Towing_and_Articulation', 'Vehicle_Manoeuvre',
#        'Vehicle_Location-Restricted_Lane', 'Junction_Location',
#        'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
#        'Vehicle_Leaving_Carriageway'],
#       dtype='object')

# %%
for i in range(3,10):
    print(db[db.columns[i]].value_counts()/db[db.columns[i]].count())
# Out:
# No tow/articulation           0.978189
# Articulated vehicle           0.010390
# -1                            0.005945
# Single trailer                0.003299
# Other tow                     0.001352
# Caravan                       0.000604
# Double or multiple trailer    0.000222
# Name: Towing_and_Articulation, dtype: float64
# Going ahead other                      0.483209
# Turning right                          0.095490
# Slowing or stopping                    0.074377
# Waiting to go - held up                0.060127
# Moving off                             0.045873
# Parked                                 0.041005
# Going ahead right-hand bend            0.035033
# Turning left                           0.033144
# Going ahead left-hand bend             0.030247
# Overtaking moving vehicle - offside    0.019199
# Waiting to turn right                  0.014834
# Reversing                              0.014077
# Overtaking static vehicle - offside    0.011129
# ...
